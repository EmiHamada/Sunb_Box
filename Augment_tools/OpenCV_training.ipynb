# %% [markdown]
# <a href="https://colab.research.google.com/github/EmiHamada/Sunb_Box/blob/master/Augment_tools/OpenCV_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [OpenCV公式チュートリアル](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_table_of_contents_imgproc/py_table_of_contents_imgproc.html#py-table-of-content-imgproc)
#
# [公式リファレンス](http://opencv.jp/opencv-2svn/cpp/index.html)

# %%
! pip install opencv_python
# Out:
# Requirement already satisfied: opencv_python in /usr/local/lib/python3.6/dist-packages (3.4.7.28)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv_python) (1.17.4)

# %%
import cv2
print(cv2.__version__)
# Out:
# 3.4.3

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !wget https://github.com/kawashimaken/photos/raw/master/kawashima01.jpg
# Out:
# --2019-11-27 06:04:27--  https://github.com/kawashimaken/photos/raw/master/kawashima01.jpg
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kawashimaken/photos/master/kawashima01.jpg [following]
# --2019-11-27 06:04:28--  https://raw.githubusercontent.com/kawashimaken/photos/master/kawashima01.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16073 (16K) [image/jpeg]
# Saving to: ‘kawashima01.jpg’
#
# kawashima01.jpg     100%[===================>]  15.70K  --.-KB/s    in 0.006s
#
# 2019-11-27 06:04:28 (2.50 MB/s) - ‘kawashima01.jpg’ saved [16073/16073]

# %%
# !ls -la
# Out:
# total 32
# drwxr-xr-x 1 root root  4096 Nov 27 06:04 .
# drwxr-xr-x 1 root root  4096 Nov 27 05:47 ..
# drwxr-xr-x 1 root root  4096 Nov 21 16:30 .config
# -rw-r--r-- 1 root root 16073 Nov 27 06:04 kawashima01.jpg
# drwxr-xr-x 1 root root  4096 Nov 21 16:30 sample_data

# %%
img_bgr = cv2.imread('kawashima01.jpg')
print(img_bgr)
# Out:
# [[[183 219 219]
#   [178 214 214]
#   [168 206 206]
#   ...
#   [255 253 253]
#   [255 252 252]
#   [255 250 250]]
#
#  [[175 212 216]
#   [170 209 211]
#   [164 202 206]
#   ...
#   [255 251 251]
#   [255 251 251]
#   [255 250 250]]
#
#  [[163 204 213]
#   [161 203 210]
#   [157 198 207]
#   ...
#   [255 247 247]
#   [255 249 249]
#   [255 251 251]]
#
#  ...
#
#  [[226 216 255]
#   [202 190 255]
#   [170 154 232]
#   ...
#   [158 165 198]
#   [187 195 225]
#   [207 217 247]]
#
#  [[224 215 255]
#   [200 189 252]
#   [166 150 227]
#   ...
#   [143 149 186]
#   [177 183 218]
#   [203 212 245]]
#
#  [[223 214 255]
#   [197 186 248]
#   [164 148 225]
#   ...
#   [134 139 178]
#   [171 177 214]
#   [200 209 243]]]

# %%
plt.imshow(img_bgr)
plt.show()

# %%
import numpy as np

x = np.array(img_bgr)
print(x.shape)
# Out:
# (320, 320, 3)

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
plt.imshow(img_hsv)
plt.show()

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)
plt.show()

# %%
cv2.imwrite('gray_kawashima.jpg', img_gray)
# Out:
# True

# %%
! ls
# Out:
# gray_kawashima.jpg  kawashima01.jpg  sample_data

# %%
img_bgr = cv2.imread('kawashima01.jpg')

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

size = img_rgb.shape
print(size)
# Out:
# (320, 320, 3)

# %%
size[2]
# Out:
# 3

# %%
new_img = img_rgb[:size[0] // 2, :size[1] // 2]
print(new_img.shape)

plt.imshow(new_img)
plt.show()
# Out:
# (160, 160, 3)

# %%
new_img = img_rgb[size[0] // 2:, size[1] // 2:]
print(new_img.shape)

plt.imshow(new_img)
plt.show()
# Out:
# (160, 160, 3)

# %%
new_img = img_rgb[:size[0] // 3, :size[1] // 3]
print(new_img.shape)

plt.imshow(new_img)
plt.show()
# Out:
# (106, 106, 3)

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

size = img_rgb.shape
print(size)
resized_img = cv2.resize(img_rgb, (img_rgb.shape[0]*2, img_rgb.shape[1]*2))

print(resized_img.shape)

plt.imshow(resized_img)
plt.show()
# Out:
# (320, 320, 3)
# (640, 640, 3)

# %%
resized_img[0][0]
# Out:
# array([219, 219, 183], dtype=uint8)

# %%
img_rgb[0][0]
# Out:
# array([219, 219, 183], dtype=uint8)

# %%
resized_img = cv2.resize(img_rgb, (img_rgb.shape[0]//4, img_rgb.shape[1]//4))

print(resized_img.shape)

plt.imshow(resized_img)
plt.show()
# Out:
# (80, 80, 3)

# %%
resized_img = cv2.resize(img_rgb, (img_rgb.shape[0]//10, img_rgb.shape[1]//10))

print(resized_img.shape)

plt.imshow(resized_img)
plt.show()
# Out:
# (32, 32, 3)

# %%
resized_img[0][0]
# Out:
# array([208, 190, 142], dtype=uint8)

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

mat = cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2), 45, 1.0)

result_img = cv2.warpAffine(img_rgb, mat, img_rgb.shape2[:2])

plt.imshow(result_img)
plt.show()

# %%
mat = cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2), 135, 0.5)

result_img = cv2.warpAffine(img_rgb, mat, img_rgb.shape[:2])

plt.imshow(result_img)
plt.show()

# %%
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')

result_img = cv2.cvtColor(img_bgr, cv2.COLOR_RGB2LAB)

plt.imshow(result_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

retval, result_img = cv2.threshold(img_rgb, 95, 128, cv2.THRESH_TOZERO)

plt.imshow(result_img)
plt.show()

# %%
retval, result_img = cv2.threshold(img_rgb, 100, 255, cv2.THRESH_BINARY)

plt.imshow(result_img)
plt.show()

# %%
img_rgb.size
# Out:
# 307200

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

result_img = cv2.GaussianBlur(img_rgb, (15, 15), 0)

plt.imshow(result_img)
plt.show()

# %%
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

result_img = cv2.fastNlMeansDenoisingColored(img_rgb)

plt.imshow(result_img)
plt.show()

# %%
plt.imshow(img_rgb)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

flit = np.array([[0, 1, 0],
                [1, 0, 1],
                [0, 1, 0]], np.uint8)

result_img = cv2.dilate(img_rgb, flit)

plt.imshow(result_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

flit = np.array([[0, 1, 0],
                [1, 0, 1],
                [0, 1, 0]], np.uint8)

result_img = cv2.erode(img_rgb, flit)

plt.imshow(result_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

img_bgr = cv2.imread('kawashima01.jpg')
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

retval, thresh = cv2.threshold(img_gray, 88, 255, 0)

img, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

result_img = cv2.drawContours(img, contours, -1, (0, 0, 255), 3)

plt.imshow(result_img)
plt.show()
